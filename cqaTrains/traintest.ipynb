# %%
from datasets import load_dataset
from transformers import AutoModelForCausalLM, AutoTokenizer

ds = load_dataset("rajpurkar/squad")

model = AutoModelForCausalLM.from_pretrained("../distillLLAMA2")
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B-Instruct")

# %%
import pandas as pd

train_dataset=ds["train"].shuffle(seed=42).select(range(1000))

# %%
max_length=0
for i in range(1000):
    data=train_dataset[i]
    tokenized = tokenizer(train_dataset[i]['context']+train_dataset[i]['question'] + train_dataset[i]['answers']['text'][0])
    max_length = len(tokenized['input_ids']) if len(tokenized['input_ids']) > max_length   else max_length

print(max_length)
# Out:
# 495

# %%
tokenizer.pad_token = tokenizer.eos_token
tokenizer.pad_token_id = tokenizer.eos_token_id
tokenized = tokenizer(train_dataset[0]['context']+train_dataset[0]['question'] + train_dataset[0]['answers']['text'][0], padding="max_length", max_length=512, truncation=True, return_tensors="pt")

# %%
import torch
sum=torch.sum(tokenized['attention_mask'])
cqlen=len(tokenizer(train_dataset[0]['context']+train_dataset[0]['question'])['input_ids'])
tokenized2 = tokenizer(train_dataset[0]['context']+train_dataset[0]['question'] + train_dataset[0]['answers']['text'][0])
cqlen
# Out:
# 143

# %%
tokenized['input_ids'][0]
# Out:
# tensor([128000,    791,  57717,  17997,    389,  44193,    612,   3142,   9601,
#          21467,  15212,    439,    279,  18172,  12047,   3224,    304,    279,
#           1917,    369,  10597,  11542,     13,    578,   3723,   4273,   9849,
#            389,   7327,  53176,  25320,     11,    264,  52008,   9678,   9266,
#            315,    279,   2326,   3109,     11,    706,   9277,  15212,    389,
#           1202,   3821,   1160,    315,   5961,    430,   1397,   3345,  16967,
#           4245,    311,    279,   7138,    323,  13112,    315,  27655,    315,
#          10597,  11542,  17045,    304,    477,  66441,    555,    279,   3109,
#             13,  10771,    311,    264,    220,    679,     15,  57717,   8121,
#           7867,  21237,  10795,     11,    220,   5833,      4,    315,  82604,
#          84721,   7396,    279,   4648,  16750,    369,   1884,    889,   5387,
#          15256,     26,    220,   2813,      4,   7396,    421,   2877,    826,
# ...
